# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
# ----====: TESTING : logging_utils.py :=====------------------------------------------------------------------

import sys
PROJECT_ROOT = "/Workspace/Users/rohan.m.mukherjee@gmail.com/bfsi-lakehouse-databricks"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
print(f"✓ Project root added to sys.path: {PROJECT_ROOT}")

import time
from utils.logging_utils import start_etl_run, log_table_start, log_table_end, end_etl_run

t0 = time.time()
run_id = start_etl_run(pipeline_name="TEST_RUN", process_type="BRONZE", run_dt="2024-01-01")
t1 = time.time(); print(f"start_etl_run: {t1-t0:.2f}s")

log_id = log_table_start(run_id=run_id, table_id=1, table_name="test_table1",
                          process_type="BRONZE", load_type="FULL", run_dt="2024-01-01")
t2 = time.time(); print(f"log_table_start: {t2-t1:.2f}s")

log_table_end(log_id=log_id, status="SUCCESS", rows_read=100, rows_written=100, delta_version_after=1)
t3 = time.time(); print(f"log_table_end: {t3-t2:.2f}s")

end_etl_run(run_id=run_id)
t4 = time.time(); print(f"end_etl_run: {t4-t3:.2f}s")

print(f"\nTotal: {t4-t0:.2f}s")

# %%
# ----====: TESTING : settings.py :=====------------------------------------------------------------------
import sys
PROJECT_ROOT = "/Workspace/Users/rohan.m.mukherjee@gmail.com/bfsi-lakehouse-databricks"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
print(f"✓ Project root added to sys.path: {PROJECT_ROOT}")

import settings as config

print(f"Environment       : {config.get_env()}")
print(f"Catalog           : {config.CATALOG}")
print(f"Metadata FQNs     :")
for t in (config.TBL_TABLE_CONFIG, config.TBL_TABLE_PROCESS_CONFIG,
          config.TBL_INPUT_COLUMN_CONFIG, config.TBL_ETL_PROCESS_MASTER,
          config.TBL_ETL_PROCESS_LOG, config.TBL_SCHEMA_DRIFT_LOG):
    print(f"  - {t}")
print(f"Raw path template : {config.RAW_PATH_TEMPLATE}")
print(f"Audit columns     : {config.AUDIT_COLS.as_list()}")
print(f"Drift policies    : {[p.value for p in config.DriftPolicy]}")
print(f"Load statuses     : {[s.value for s in config.LoadStatus]}")

# %%
import os
print("DATABRICKS_RUNTIME_VERSION:", os.environ.get("DATABRICKS_RUNTIME_VERSION"))
print("IS_SERVERLESS:", os.environ.get("IS_SERVERLESS"))
print("Detected env:", config.get_env())

# %%
import os
PROJECT_ROOT = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
print(PROJECT_ROOT)
