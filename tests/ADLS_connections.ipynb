# %%
# dbutils.fs.ls('abfss://raw@bfsilakehouse.dfs.core.windows.net/')

dbutils.fs.ls('abfss://raw@bfsilakehouse.dfs.core.windows.net/t_Loan/')

# %%
# Go all the way to parquet files
dbutils.fs.ls('abfss://raw@bfsilakehouse.dfs.core.windows.net/t_Loan/dt=2024-01-02/batch=1/')
